# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('temp_change_pk.csv')

#df.head()
df1 =df.loc[10:50,['Area','Value']]
df1.head(5)
# Out:
#         Area  Value
# 10  Pakistan -0.826
# 11  Pakistan  0.438
# 12  Pakistan -1.750
# 13  Pakistan -0.221
# 14  Pakistan -0.716

# %%
df1['Area'].astype(object)
# Out:
# 10    Pakistan
# 11    Pakistan
# 12    Pakistan
# 13    Pakistan
# 14    Pakistan
# 15    Pakistan
# 16    Pakistan
# 17    Pakistan
# 18    Pakistan
# 19    Pakistan
# 20    Pakistan
# 21    Pakistan
# 22    Pakistan
# 23    Pakistan
# 24    Pakistan
# 25    Pakistan
# 26    Pakistan
# 27    Pakistan
# 28    Pakistan
# 29    Pakistan
# 30    Pakistan
# 31    Pakistan
# 32    Pakistan
# 33    Pakistan
# 34    Pakistan
# 35    Pakistan
# 36    Pakistan
# 37    Pakistan
# 38    Pakistan
# 39    Pakistan
# 40    Pakistan
# 41    Pakistan
# 42    Pakistan
# 43    Pakistan
# 44    Pakistan
# 45    Pakistan
# 46    Pakistan
# 47    Pakistan
# 48    Pakistan
# 49    Pakistan
# 50    Pakistan
# Name: Area, dtype: object

# %%
x = df1['Area']
y = df1['Value']

# %%
df1.isnull().sum()
# Out:
# Area     0
# Value    0
# dtype: int64

# %%
df1.shape
# Out:
# (41, 2)

# %%
sns.scatterplot(x="Year", y="Value",
                hue="Area",palette= 'deep',
                sizes=(1, 8), linewidth=0,
                data=df)
# Out:
# <Axes: xlabel='Year', ylabel='Value'>

# %%
import seaborn as sns
#sns.set_theme(style="darkgrid")


# Plot the responses for different events and regions
sns.lineplot(x="Year", y="Value",
             data=df)
# Out:
# <Axes: xlabel='Year', ylabel='Value'>

# %%
df1.hist(color='blue',bins=10,figsize=(6,4))
# Out:
# array([[<Axes: title={'center': 'Value'}>]], dtype=object)
