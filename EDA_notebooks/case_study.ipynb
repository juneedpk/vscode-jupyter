# %% [markdown]
#    # Pandas case study
#
#    # we will check the data from kashti set

# %%
#import libraries

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
kashti = sns.load_dataset('titanic')

kashti.to_csv('kashti.to_csv') #saving file to csv format

# %%
kashti.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#droping few columns and make new data set

new_kashti=kashti.drop(['pclass','sibsp','parch'],axis=1)
new_kashti.head()
# Out:
#    survived     sex   age     fare embarked  class    who  adult_male deck  \
# 0         0    male  22.0   7.2500        S  Third    man        True  NaN
# 1         1  female  38.0  71.2833        C  First  woman       False    C
# 2         1  female  26.0   7.9250        S  Third  woman       False  NaN
# 3         1  female  35.0  53.1000        S  First  woman       False    C
# 4         0    male  35.0   8.0500        S  Third    man        True  NaN
#
#    embark_town alive  alone
# 0  Southampton    no  False
# 1    Cherbourg   yes  False
# 2  Southampton   yes   True
# 3  Southampton   yes  False
# 4  Southampton    no   True

# %%
kashti.drop(['pclass','sibsp','parch'],axis=1).head()
# Out:
#    survived     sex   age     fare embarked  class    who  adult_male deck  \
# 0         0    male  22.0   7.2500        S  Third    man        True  NaN
# 1         1  female  38.0  71.2833        C  First  woman       False    C
# 2         1  female  26.0   7.9250        S  Third  woman       False  NaN
# 3         1  female  35.0  53.1000        S  First  woman       False    C
# 4         0    male  35.0   8.0500        S  Third    man        True  NaN
#
#    embark_town alive  alone
# 0  Southampton    no  False
# 1    Cherbourg   yes  False
# 2  Southampton   yes   True
# 3  Southampton   yes  False
# 4  Southampton    no   True

# %%
kashti.mean()
# Out:
# C:\Users\AI\AppData\Local\Temp\ipykernel_10332\3332994036.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   kashti.mean()
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# adult_male     0.602694
# alone          0.602694
# dtype: float64

# %%
kashti.value_counts(['survived']).plot(kind='barh')
# Out:
# <AxesSubplot: ylabel='survived'>

# %%
kashti.groupby(['sex']).mean()
# Out:
# C:\Users\AI\AppData\Local\Temp\ipykernel_10332\2662322673.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   kashti.groupby(['sex']).mean()
#         survived    pclass        age     sibsp     parch       fare  \
# sex
# female  0.742038  2.159236  27.915709  0.694268  0.649682  44.479818
# male    0.188908  2.389948  30.726645  0.429809  0.235702  25.523893
#
#         adult_male     alone
# sex
# female    0.000000  0.401274
# male      0.930676  0.712305

# %%
kashti.groupby(['sex','class']).mean()
# Out:
# C:\Users\AI\AppData\Local\Temp\ipykernel_10332\1290292799.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   kashti.groupby(['sex','class']).mean()
#                survived  pclass        age     sibsp     parch        fare  \
# sex    class
# female First   0.968085     1.0  34.611765  0.553191  0.457447  106.125798
#        Second  0.921053     2.0  28.722973  0.486842  0.605263   21.970121
#        Third   0.500000     3.0  21.750000  0.895833  0.798611   16.118810
# male   First   0.368852     1.0  41.281386  0.311475  0.278689   67.226127
#        Second  0.157407     2.0  30.740707  0.342593  0.222222   19.741782
#        Third   0.135447     3.0  26.507589  0.498559  0.224784   12.661633
#
#                adult_male     alone
# sex    class
# female First     0.000000  0.361702
# ...

# %%
#childern and women are first
kashti[kashti['age']<18].mean()
# Out:
# C:\Users\AI\AppData\Local\Temp\ipykernel_10332\1531501306.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   kashti[kashti['age']<18].mean()
# survived       0.539823
# pclass         2.584071
# age            9.041327
# sibsp          1.460177
# parch          1.053097
# fare          31.220798
# adult_male     0.159292
# alone          0.203540
# dtype: float64

# %%
#childern survived
kashti[kashti['age']<18].groupby(['sex','class']).mean()
# Out:
# C:\Users\AI\AppData\Local\Temp\ipykernel_10332\2774936305.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   kashti[kashti['age']<18].groupby(['sex','class']).mean()
#                survived  pclass        age     sibsp     parch        fare  \
# sex    class
# female First   0.875000     1.0  14.125000  0.500000  0.875000  104.083337
#        Second  1.000000     2.0   8.333333  0.583333  1.083333   26.241667
#        Third   0.542857     3.0   8.428571  1.571429  1.057143   18.727977
# male   First   1.000000     1.0   8.230000  0.500000  2.000000  116.072900
#        Second  0.818182     2.0   4.757273  0.727273  1.000000   25.659473
#        Third   0.232558     3.0   9.963256  2.069767  1.000000   22.752523
#
#                adult_male     alone
# sex    class
# ...
