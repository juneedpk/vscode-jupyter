# %% [markdown]
# ## import libraries
#
# - pandas
# - matplotlib
# - seaborn
# - numpy

# %%
import pandas as pd
from numpy import median
import matplotlib.pyplot as plt
import seaborn as sns

fuel = pd.read_csv("FuelConsumption.csv")
    
# fuel.head()    
# iris = sns.load_dataset('iris')



sns.lineplot(x='VEHICLECLASS', y='ENGINESIZE',data=fuel)
# plt.xlabel('comparison of flower',size=24)
# plt.ylabel('what is size',size=20)
# plt.title("graph of iris",size=14,weight='bold')
sns.set(rc={"figure.figsize":(20, 10)})

# sns.set_style('dark')
# sns.set_style(style='event',rc=None)


plt.show()

# %%
import pandas as pd
from numpy import median
import matplotlib.pyplot as plt
import seaborn as sns

fuel = pd.read_csv("FuelConsumption.csv")
    
# ads.describe() 
# kashti = sns.load_dataset('titanic')

sns.barplot(x='VEHICLECLASS',y='ENGINESIZE',linewidth=1,errcolor='0.3',edgecolor='0.5',data=fuel,palette='dark')
# plt.xlabel('comparison of sex',size=24)
# plt.ylabel('what is age',size=20)
# plt.title("graph of titanic",size=14)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

ads = pd.read_csv("social.csv")
# kashti = sns.load_dataset('titanic')

# kashti.head()

sns.boxplot(x='Age',y='EstimatedSalary',data=ads,dodge=True,saturation=0.3,palette='dark',showmeans=True,meanprops={'marker':'*','markersize':'24','markeredgecolor':'blue'})

# plt.xlabel('comparison of sex',size=24)
# plt.ylabel('what is age',size=20)
# plt.title("graph of titanic",size=14,weight='bold')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='EstimatedSalary'>
