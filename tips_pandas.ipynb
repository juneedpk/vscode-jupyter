# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'a':[1,2,3,4],'b':['ali','anser','farhan','javaid']})

df
# Out:
#    a       b
# 0  1     ali
# 1  2   anser
# 2  3  farhan
# 3  4  javaid

# %%
arr = np.array([[1,2,3],[3,4,5],[6,7,8]])
pd.DataFrame(arr)
# Out:
#    0  1  2
# 0  1  2  3
# 1  3  4  5
# 2  6  7  8

# %%
rd = pd.DataFrame(np.random.randn(3,4),columns=('v1','v2','v3','v4'))
rd
# Out:
#          v1        v2        v3        v4
# 0  0.017329 -1.243000 -1.069754  1.095345
# 1  1.888724  0.800414  0.446476  0.284031
# 2  0.505386 -0.488810  0.155487 -0.947886

# %%
rd.rename(columns=({'v1':'value1'}),inplace=True)

rd
# Out:
#      value1        v2        v3        v4
# 0  0.017329 -1.243000 -1.069754  1.095345
# 1  1.888724  0.800414  0.446476  0.284031
# 2  0.505386 -0.488810  0.155487 -0.947886

# %%
rd.add_prefix('set')
# Out:
#    setvalue1     setv2     setv3     setv4
# 0   0.017329 -1.243000 -1.069754  1.095345
# 1   1.888724  0.800414  0.446476  0.284031
# 2   0.505386 -0.488810  0.155487 -0.947886

# %%
import seaborn as sns

# %%
phool = sns.load_dataset('iris')
phool.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
phool.iloc[:,::-1]
# Out:
#        species  petal_width  petal_length  sepal_width  sepal_length
# 0       setosa          0.2           1.4          3.5           5.1
# 1       setosa          0.2           1.4          3.0           4.9
# 2       setosa          0.2           1.3          3.2           4.7
# 3       setosa          0.2           1.5          3.1           4.6
# 4       setosa          0.2           1.4          3.6           5.0
# ..         ...          ...           ...          ...           ...
# 145  virginica          2.3           5.2          3.0           6.7
# 146  virginica          1.9           5.0          2.5           6.3
# 147  virginica          2.0           5.2          3.0           6.5
# 148  virginica          2.3           5.4          3.4           6.2
# 149  virginica          1.8           5.1          3.0           5.9
#
# [150 rows x 5 columns]

# %%
df.dtypes
# Out:
# a     int64
# b    object
# dtype: object

# %%
phool.select_dtypes('object')
# Out:
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 1 columns]

# %%
phool.shape
# Out:
# (150, 5)

# %% [markdown]
# ### joining and spliting  datasets

# %%
phool1 = phool.sample(frac=0.25,random_state=1)
phool1.shape
# Out:
# (38, 5)

# %%
phool2 = phool.drop(phool1.index)
phool2.shape
# Out:
# (112, 5)

# %%
phool0 = phool1.append(phool2)
phool0.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# e:\vscode\vscode-jupyter-1\tips_pandas.ipynb Cell 16 line 1
# ----> <a href='vscode-notebook-cell:/e%3A/vscode/vscode-jupyter-1/tips_pandas.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> phool0 = phool1.append(phool2)
#       <a href='vscode-notebook-cell:/e%3A/vscode/vscode-jupyter-1/tips_pandas.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> phool0.shape
#
# File c:\Users\AI\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6202, in NDFrame.__getattr__(self, name)
#    6195 if (
#    6196     name not in self._internal_names_set
#    6197     and name not in self._metadata
#    6198     and name not in self._accessors
#    6199     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6200 ):
#    6201     return self[name]
# -> 6202 return object.__getattribute__(self, name)
#
# ...

# %%
phool.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# ### filtering data

# %%
phool[(phool.species=='setosa')]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
phool[(phool.species=='setosa') & (phool.sepal_length>3)].shape
# Out:
# (50, 5)

# %%
phool[(phool.species.isin(['setosa','versicolor']))].shape
# Out:
# (100, 5)

# %%
phool.species.value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
phool.sepal_length.value_counts().nlargest(3)
# Out:
# 5.0    10
# 5.1     9
# 6.3     9
# Name: sepal_length, dtype: int64

# %%
df = pd.DataFrame({'Name': ['Steve Smith', 'Joe Nadal','Roger Federer'],'Age':[32, 34, 36]})
df
# Out:
#             Name  Age
# 0    Steve Smith   32
# 1      Joe Nadal   34
# 2  Roger Federer   36

# %%
df[['first','last']]= df.Name.str.split(' ',expand=True)
df
# Out:
#             Name  Age  first     last
# 0    Steve Smith   32  Steve    Smith
# 1      Joe Nadal   34    Joe    Nadal
# 2  Roger Federer   36  Roger  Federer

# %%
ti = sns.load_dataset('titanic')
ti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
ti.groupby('sex').count()
# Out:
#         survived  pclass  age  sibsp  parch  fare  embarked  class  who  \
# sex
# female       314     314  261    314    314   314       312    314  314
# male         577     577  453    577    577   577       577    577  577
#
#         adult_male  deck  embark_town  alive  alone
# sex
# female         314    97          312    314    314
# male           577   106          577    577    577

# %%
ti.groupby('who').count()
# Out:
#        survived  pclass  sex  age  sibsp  parch  fare  embarked  class  \
# who
# child        83      83   83   83     83     83    83        83     83
# man         537     537  537  413    537    537   537       537    537
# woman       271     271  271  218    271    271   271       269    271
#
#        adult_male  deck  embark_town  alive  alone
# who
# child          83    13           83     83     83
# man           537    99          537    537    537
# woman         271    91          269    271    271

# %%
len(ti.groupby('who'))
# Out:
# 3

# %%
ti.groupby(['who','embark_town']).count()
# Out:
#                    survived  pclass  sex  age  sibsp  parch  fare  embarked  \
# who   embark_town
# child Cherbourg          18      18   18   18     18     18    18        18
#       Queenstown          5       5    5    5      5      5     5         5
#       Southampton        60      60   60   60     60     60    60        60
# man   Cherbourg          90      90   90   64     90     90    90        90
#       Queenstown         37      37   37   12     37     37    37        37
#       Southampton       410     410  410  337    410    410   410       410
# woman Cherbourg          60      60   60   48     60     60    60        60
#       Queenstown         35      35   35   11     35     35    35        35
#       Southampton       174     174  174  157    174    174   174       174
#
#                    class  adult_male  deck  alive  alone
# who   embark_town
# child Cherbourg       18          18     0     18     18
# ...

# %%
ti.groupby(['who','embark_town']).survived.count().plot(kind='barh')
# Out:
# <Axes: ylabel='who,embark_town'>

# %%
ti['sex_num']=ti.sex.map({'male':1,'female':0})
ti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
ti['who_num']=ti.who.map({'man':1,'woman':0})
ti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
mars = pd.read_csv('mars_dataset.csv')
mars.head()
# Out:
#          earth_date_time max_ground_temp min_ground_temp max_air_temp  \
# 0  Earth, 2022-01-26 UTC              -3             -71           10
# 1  Earth, 2022-01-25 UTC              -3             -72           10
# 2  Earth, 2022-01-24 UTC              -4             -70            8
# 3  Earth, 2022-01-23 UTC              -6             -70            9
# 4  Earth, 2022-01-22 UTC              -7             -71            8
#
#   min_air_temp mean_pressure sunrise sunset uv_radiation weather
# 0          -84           707    5:25  17:20     moderate   Sunny
# 1          -87           707    5:25  17:20     moderate   Sunny
# 2          -81           708    5:25  17:21     moderate   Sunny
# 3          -91           707    5:26  17:21     moderate   Sunny
# 4          -92           708    5:26  17:21     moderate   Sunny

# %%
mars.isnull().sum()
# Out:
# earth_date_time     0
# max_ground_temp     0
# min_ground_temp     0
# max_air_temp        0
# min_air_temp        0
# mean_pressure       0
# sunrise             0
# sunset              0
# uv_radiation       27
# weather             0
# dtype: int64

# %%
mars.dropna(subset='uv_radiation',inplace=True)

# %%
mars.isnull().sum()
# Out:
# earth_date_time    0
# max_ground_temp    0
# min_ground_temp    0
# max_air_temp       0
# min_air_temp       0
# mean_pressure      0
# sunrise            0
# sunset             0
# uv_radiation       0
# weather            0
# dtype: int64

# %%
mars.shape
# Out:
# (3170, 10)

# %%
mars.groupby('uv_radiation').count().plot(kind='barh')
# Out:
# <Axes: ylabel='uv_radiation'>

# %%
mars_split = mars.sample(frac=0.50,random_state=1)
mars_split.shape
# Out:
# (1598, 10)

# %%
mars2 = mars.drop(mars_split.index)
mars2.shape
# Out:
# (1599, 10)

# %%
mars.dtypes
# Out:
# earth_date_time    object
# max_ground_temp    object
# min_ground_temp    object
# max_air_temp       object
# min_air_temp       object
# mean_pressure      object
# sunrise            object
# sunset             object
# uv_radiation       object
# weather            object
# dtype: object

# %%
mars.select_dtypes('object')
# Out:
#             earth_date_time      max_ground_temp      min_ground_temp  \
# 0     Earth, 2022-01-26 UTC                   -3                  -71
# 1     Earth, 2022-01-25 UTC                   -3                  -72
# 2     Earth, 2022-01-24 UTC                   -4                  -70
# 3     Earth, 2022-01-23 UTC                   -6                  -70
# 4     Earth, 2022-01-22 UTC                   -7                  -71
# ...                     ...                  ...                  ...
# 3192  Earth, 2012-08-18 UTC                  -18                  -76
# 3193  Earth, 2012-08-17 UTC                  -11                  -76
# 3194  Earth, 2012-08-16 UTC                  -16                  -75
# 3195  Earth, 2012-08-15 UTC  Value not available  Value not available
# 3196  Earth, 2012-08-07 UTC  Value not available  Value not available
#
#              max_air_temp         min_air_temp        mean_pressure sunrise  \
# ...

# %%
mars.replace({'Value not available':'Nan'},inplace=True)

# %%
mars['weather']=mars['weather'].astype('category')

# %%
mars.dtypes
# Out:
# earth_date_time      object
# max_ground_temp      object
# min_ground_temp      object
# max_air_temp         object
# min_air_temp         object
# mean_pressure        object
# sunrise              object
# sunset               object
# uv_radiation         object
# weather            category
# dtype: object

# %%
mars.select_dtypes('category')
# Out:
#      weather
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 3192       0
# 3193       0
# 3194       0
# 3195       0
# 3196       0
#
# [3197 rows x 1 columns]

# %%
ti['age_class']=pd.cut(ti.age,bins=[0,18,35,99],labels=['child','young','adult'])

# %%
ti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone age_class
# 0    man        True  NaN  Southampton    no  False     young
# 1  woman       False    C    Cherbourg   yes  False     adult
# 2  woman       False  NaN  Southampton   yes   True     young
# 3  woman       False    C  Southampton   yes  False     young
# 4    man        True  NaN  Southampton    no   True     young

# %%
ti.groupby('age_class').survived.count().plot(kind='barh')
# Out:
# C:\Users\AI\AppData\Local\Temp\ipykernel_10212\2416610919.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ti.groupby('age_class').survived.count().plot(kind='barh')
# <Axes: ylabel='age_class'>

# %%
mars[['planet','date']]=mars.earth_date_time.str.split(',',expand=True)

# %%
mars.drop('earth_date_time',axis=1,inplace=True)

# %%
mars.head()
# Out:
#   max_ground_temp min_ground_temp max_air_temp min_air_temp mean_pressure  \
# 0              -3             -71           10          -84           707
# 1              -3             -72           10          -87           707
# 2              -4             -70            8          -81           708
# 3              -6             -70            9          -91           707
# 4              -7             -71            8          -92           708
#
#   sunrise sunset uv_radiation weather planet             date
# 0    5:25  17:20     moderate       0  Earth   2022-01-26 UTC
# 1    5:25  17:20     moderate       0  Earth   2022-01-25 UTC
# 2    5:25  17:21     moderate       0  Earth   2022-01-24 UTC
# 3    5:26  17:21     moderate       0  Earth   2022-01-23 UTC
# 4    5:26  17:21     moderate       0  Earth   2022-01-22 UTC

# %%
import seaborn as sns

# %%
mars.isnull().sum()
# Out:
# max_ground_temp     0
# min_ground_temp     0
# max_air_temp        0
# min_air_temp        0
# mean_pressure       0
# sunrise             0
# sunset              0
# uv_radiation       27
# weather             0
# planet              0
# date                0
# dtype: int64

# %%
sns.heatmap(ti.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
sns.lmplot(x='age',y='fare',data=ti,hue='sex')
# Out:
# c:\Users\AI\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\AI\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\AI\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
