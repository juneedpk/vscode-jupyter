# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sketch

# %%
fl = pd.read_csv('FuelConsumption.csv')
fl.head(5)
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS
# 0       2014  ACURA         ILX      COMPACT         2.0          4  \
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY
# 0          AS5        Z                   9.9                  6.7  \
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
fl.size
# Out:
# 13871

# %%
fl.shape
# Out:
# (1067, 13)

# %%
fl.describe()
# Out:
#        MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count     1067.0  1067.000000  1067.000000           1067.000000
# mean      2014.0     3.346298     5.794752             13.296532
# std          0.0     1.415895     1.797447              4.101253
# min       2014.0     1.000000     3.000000              4.600000
# 25%       2014.0     2.000000     4.000000             10.250000
# 50%       2014.0     3.400000     6.000000             12.600000
# 75%       2014.0     4.300000     8.000000             15.550000
# max       2014.0     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# std               2.794510              3.485595                  7.468702
# min               4.900000              4.700000                 11.000000
# ...

# %%
fl.isnull().sum()
# Out:
# MODELYEAR                   0
# MAKE                        0
# MODEL                       0
# VEHICLECLASS                0
# ENGINESIZE                  0
# CYLINDERS                   0
# TRANSMISSION                0
# FUELTYPE                    0
# FUELCONSUMPTION_CITY        0
# FUELCONSUMPTION_HWY         0
# FUELCONSUMPTION_COMB        0
# FUELCONSUMPTION_COMB_MPG    0
# CO2EMISSIONS                0
# dtype: int64

# %%
fl.columns
# Out:
# Index(['MODELYEAR', 'MAKE', 'MODEL', 'VEHICLECLASS', 'ENGINESIZE', 'CYLINDERS',
#        'TRANSMISSION', 'FUELTYPE', 'FUELCONSUMPTION_CITY',
#        'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
#        'FUELCONSUMPTION_COMB_MPG', 'CO2EMISSIONS'],
#       dtype='object')

# %%
sns.barplot(fl,x='CO2EMISSIONS',y='VEHICLECLASS').set_title('CO2 Emissions vs Vehicle Class')
# Out:
# Text(0.5, 1.0, 'CO2 Emissions vs Vehicle Class')

# %%
sns.heatmap(fl.corr(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sns.heatmap(fl.corr(),annot=True)
#
# File c:\Users\AI\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10059, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10057 cols = data.columns
#   10058 idx = cols.copy()
# > 10059 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10061 if method == "pearson":
#   10062     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\AI\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
# ...

# %%
sns.pairplot(fl,hue='MAKE',vars=['CO2EMISSIONS','FUELCONSUMPTION_COMB'])

# %%
 

fig = sns.kdeplot(fl[['FUELCONSUMPTION_HWY','FUELCONSUMPTION_CITY']],color="r",fill=True)
#fig = sns.kdeplot(fl['FUELCONSUMPTION_CITY'], color="b",fill=True)

# %%
fl.select_dtypes(include='object')
# Out:
#        MAKE       MODEL    VEHICLECLASS TRANSMISSION FUELTYPE
# 0     ACURA         ILX         COMPACT          AS5        Z
# 1     ACURA         ILX         COMPACT           M6        Z
# 2     ACURA  ILX HYBRID         COMPACT          AV7        Z
# 3     ACURA     MDX 4WD     SUV - SMALL          AS6        Z
# 4     ACURA     RDX AWD     SUV - SMALL          AS6        Z
# ...     ...         ...             ...          ...      ...
# 1062  VOLVO    XC60 AWD     SUV - SMALL          AS6        X
# 1063  VOLVO    XC60 AWD     SUV - SMALL          AS6        X
# 1064  VOLVO    XC70 AWD     SUV - SMALL          AS6        X
# 1065  VOLVO    XC70 AWD     SUV - SMALL          AS6        X
# 1066  VOLVO    XC90 AWD  SUV - STANDARD          AS6        X
#
# [1067 rows x 5 columns]

# %%
fl[(fl.MAKE=='VOLVO') & (fl.CO2EMISSIONS>200)].plot(kind='bar',x='MODEL',y='CO2EMISSIONS')
# Out:
# <AxesSubplot: xlabel='MODEL'>

# %%
#df[['first-name','last-name']]= df.name.str.split(' ',expand=True)

#df['sex-num']= df.sex.map({'male':0,'female':1})

#df['embarked-num']=df.embarked.factorize()[0]

# %%
sns.catplot(x='CO2EMISSIONS',y='VEHICLECLASS',data=fl,col='MAKE',kind='box')
plt.figure(figsize=(15,10))

# %%
fl.isnull().any()
# Out:
# MODELYEAR                   False
# MAKE                        False
# MODEL                       False
# VEHICLECLASS                False
# ENGINESIZE                  False
# CYLINDERS                   False
# TRANSMISSION                False
# FUELTYPE                    False
# FUELCONSUMPTION_CITY        False
# FUELCONSUMPTION_HWY         False
# FUELCONSUMPTION_COMB        False
# FUELCONSUMPTION_COMB_MPG    False
# CO2EMISSIONS                False
# dtype: bool

# %%
sns.scatterplot(data=fl,x=('CO2EMISSIONS'),y=('VEHICLECLASS'),hue='FUELCONSUMPTION_COMB')
# Out:
# <AxesSubplot: xlabel='CO2EMISSIONS', ylabel='VEHICLECLASS'>

# %%
fl.sketch.howto('plot ENGINESIZE vs TRANSMISSION')
# Out:
# <div style="display:flex;flex-direction:row;justify-content:space-between;">
#                 <pre style="width: 100%; white-space: pre-wrap;" id="875d47f0-0076-4acc-9a4f-38b43a8e1da7">
# import matplotlib.pyplot as plt
#
# # Create a figure and axes
# fig, ax = plt.subplots()
#
# # Plot the data
# ax.scatter(fl['ENGINESIZE'], fl['TRANSMISSION'])
#
# # Set labels and title
# ax.set_xlabel('Engine Size')
# ax.set_ylabel('Transmission')
# ax.set_title('Engine Size vs Transmission')
#
# # Show the plot
# plt.show()
# </pre>
#                 <button style="height: fit-content;" onclick="navigator.clipboard.writeText(JSON.parse(atob(`...`)))">Copy</button>
#                 </div>

# %%
import matplotlib.pyplot as plt

# Create a figure and axes
fig, ax = plt.subplots()

# Plot the data
ax.scatter(fl['ENGINESIZE'], fl['TRANSMISSION'])

# Set labels and title
ax.set_xlabel('Engine Size')
ax.set_ylabel('Transmission')
ax.set_title('Engine Size vs Transmission')

# Show the plot
plt.show()
